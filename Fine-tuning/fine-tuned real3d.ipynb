# %%
#%pip install pandas h5py numpy scipy matplotlib torch torchvision torchaudio -i https://pypi.tuna.tsinghua.edu.cn/simple --break-system-packages

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import time
import h5py
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
import scipy

# %%
import scipy
data = scipy.io.loadmat('real3d.mat')
# Dc=data['DataClean']
Dn=data['DataNoisey']
print(f"noisy data dimensions: {Dn.shape}")
# Out:
# 带噪数据维度: (256, 64, 48)

# %%
def calculate_snr(clean_data, denoised_data):
    # ensure the input is a 1D vector
    norm_clean = np.linalg.norm(clean_data)  # compute the square root of the sum of squares of all elements
    norm_diff = np.linalg.norm(clean_data - denoised_data)
    
    snr = 20 * np.log10(norm_clean / norm_diff)
    return snr

# %%
def patch3d(A, l1=20, l2=15, l3=15, s1=2, s2=2, s3=2):
    """
    Optimized patch3d function using stride tricks to improve efficiency
    """
    # Pad the array if necessary to ensure dimensions are divisible by patch sizes
    pad1 = (l1 - A.shape[0] % s1) % s1
    pad2 = (l2 - A.shape[1] % s2) % s2
    pad3 = (l3 - A.shape[2] % s3) % s3
    A_padded = np.pad(A, ((0, pad1), (0, pad2), (0, pad3)), mode='constant')

    # Get new dimensions
    n1, n2, n3 = A_padded.shape
    n1_patches = (n1 - l1) // s1 + 1
    n2_patches = (n2 - l2) // s2 + 1
    n3_patches = (n3 - l3) // s3 + 1

    # Generate the sliding window view
    shape = (n1_patches, n2_patches, n3_patches, l1, l2, l3)
    strides = (s1 * A_padded.strides[0], s2 * A_padded.strides[1], s3 * A_padded.strides[2]) + A_padded.strides
    patches = np.lib.stride_tricks.as_strided(A_padded, shape=shape, strides=strides)

    # Reshape patches to (num_patches, patch_size) format
    patches = patches.reshape(-1, l1 * l2 * l3)
    return patches


def patch3d_inv(X, n1, n2, n3, l1=20, l2=15, l3=15, s1=2, s2=2, s3=2):
    """
    Reconstruct 3D data from 1D patches with optimized inverse patching.

    INPUT
    X: Patches in (num_patches, patch_size) format
    n1, n2, n3: Original 3D data dimensions
    l1, l2, l3: Patch sizes along each dimension
    s1, s2, s3: Shifts between patches along each dimension

    OUTPUT
    A: Reconstructed 3D data
    """

    # Initialize the padded 3D array and mask
    pad1 = (l1 - n1 % s1) % s1
    pad2 = (l2 - n2 % s2) % s2
    pad3 = (l3 - n3 % s3) % s3
    A = np.zeros((n1 + pad1, n2 + pad2, n3 + pad3))
    mask = np.zeros_like(A)

    # Reshape 1D patches to the 3D patch size for easier handling
    X = X.reshape(-1, l1, l2, l3)

    # Calculate the number of patches along each dimension
    n1_patches = (A.shape[0] - l1) // s1 + 1
    n2_patches = (A.shape[1] - l2) // s2 + 1
    n3_patches = (A.shape[2] - l3) // s3 + 1

    # Iterate over each patch and place it into the appropriate location
    idx = 0
    for i in range(n1_patches):
        for j in range(n2_patches):
            for k in range(n3_patches):
                # Place the current patch in the reconstruction array and update mask
                A[i * s1:i * s1 + l1, j * s2:j * s2 + l2, k * s3:k * s3 + l3] += X[idx]
                mask[i * s1:i * s1 + l1, j * s2:j * s2 + l2, k * s3:k * s3 + l3] += 1
                idx += 1

    # Avoid division by zero by replacing zeros with ones in the mask before division
    mask[mask == 0] = 1
    A /= mask

    # Trim padding to match the original dimensions
    return A[:n1, :n2, :n3]

# %%
#3D data fine-tuning
import scipy
[nz, nx, ny] = Dn.shape
w1 = 20
w2 = 15
w3 = 15
s1 = 2
s2 = 2
s3 = 2

X_noisy = patch3d(Dn, w1, w2, w3, s1, s2, s3)
X_noisy = X_noisy.astype(np.float32)

Pdata_noisy = torch.from_numpy(X_noisy)
print(Pdata_noisy.dtype)
print(f"Noisy patches shape: {X_noisy.shape}")
print(f"Noisy dtype: {X_noisy.dtype}")

total_patches = len(Pdata_noisy)

#Data split: 100% training data 
finetune_size = int(total_patches * 1.0)   
valid_size = int(total_patches * 0.0)     

finetune_noisy = Pdata_noisy[:finetune_size]           
valid_noisy = Pdata_noisy[finetune_size:finetune_size + valid_size]  

print(f"Total number of patches: {total_patches}")
print(f"Fine-tune training set shape: {finetune_noisy.shape} (100%)")
print(f"Validation set shape: {valid_noisy.shape} (0%)")
print(f"Use all data during inference: {Pdata_noisy.shape} (100%)")

# Create TensorDataset
finetune_data = TensorDataset(finetune_noisy)   
valid_data = TensorDataset(valid_noisy)        

batch_size1 = 64

finetune_loader = torch.utils.data.DataLoader(finetune_data, batch_size=batch_size1, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size1, shuffle=False)

print(f"Batch size of fine-tune training dataloade: {len(finetune_loader)}")
print(f"Batch size of validation dataloader: {len(valid_loader)}")
# Out:
# torch.float32
# Noisy patches shape: (55692, 4500)
# Noisy dtype: float32
# 总patch数: 55692
# 微调训练集形状: torch.Size([55692, 4500]) (100%)
# 验证集形状: torch.Size([0, 4500]) (0%)
# 推理时使用全部数据: torch.Size([55692, 4500]) (100%)
# 微调训练数据加载器批次数: 871
# 验证数据加载器批次数: 0

# %%
class FCB(nn.Module):
    def __init__(self, input_size, output_size, dropout=0.1):
        super().__init__()
        self.fc = nn.Linear(input_size, output_size)
        self.activation = nn.LeakyReLU(0.1, inplace=True)
        self.norm = nn.LayerNorm(output_size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        x = self.fc(x)
        x = self.activation(x)
        x = self.norm(x)
        x = self.dropout(x)
        return x

# %%
class SparseAttention(nn.Module):
    def __init__(self, dim, num_heads=4, window_size=2):
        super().__init__()
        assert dim % num_heads == 0, "dim must be divisible by num_heads"
        
        self.num_heads = num_heads
        self.head_dim = dim // num_heads
        self.scale = self.head_dim ** -0.5
        self.window_size = window_size

        self.qkv = nn.Linear(dim, dim * 3, bias=False)
        self.proj = nn.Linear(dim, dim)

    

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, self.head_dim).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]

        attn = (q @ k.transpose(-2, -1)) * self.scale

        block_size = self.window_size * 2
        num_blocks = max(1, N // block_size)  
        mask = torch.zeros(N, N, device=x.device)
        for i in range(num_blocks):
            start = i * block_size
            end = min(start + block_size, N)  # Prevent out-of-bounds errors
            mask[start:end, start:end] = 1
        mask = mask.unsqueeze(0).unsqueeze(0).bool()

        attn = attn.masked_fill(~mask, -1e9)
        attn = attn.softmax(dim=-1)

        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        x = self.proj(x)
        return x

class Sparse_PatchAE(nn.Module):
    def __init__(self, input_dim, embed_dim=256, depth=1, num_heads=4, window_size=2):
        super().__init__()
        self.input_dim = input_dim
        self.embed_dim = embed_dim

        self.embed = nn.Linear(input_dim, embed_dim)
        self.cls_token = nn.Parameter(torch.randn(1, 1, embed_dim) * 0.02)
        self.pos_embed = nn.Parameter(torch.randn(1, 2, embed_dim) * 0.02)

        self.num_heads = num_heads
        self.window_size = window_size

        self.blocks = nn.ModuleList([
            self._make_block(embed_dim) for _ in range(depth)
        ])
        self.norm = nn.LayerNorm(embed_dim)
        self.decoder = nn.Linear(embed_dim, input_dim)
        

    def _make_block(self, dim):
        return nn.ModuleList([
            nn.LayerNorm(dim),
            SparseAttention(dim, self.num_heads, self.window_size),
            nn.LayerNorm(dim),
            nn.Sequential(
                nn.Linear(dim, dim * 4),
                nn.GELU(),
                nn.Linear(dim * 4, dim)
            )
        ])

    def forward(self, x):
        B = x.shape[0]
        x = self.embed(x).unsqueeze(1)  # [B, 1, embed_dim]

        cls_tokens = self.cls_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.pos_embed

        for norm1, attn, norm2, mlp in self.blocks:
            x = x + attn(norm1(x))
            x = x + mlp(norm2(x))

        x = self.norm(x)
        patch_token = x[:, 1, :]
        recon = self.decoder(patch_token)
        return recon

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, dropout=0.1):
        super().__init__()
        self.fcb1 = FCB(input_size, 512, dropout)
        self.Sparse1 = Sparse_PatchAE(512, 512, depth=4, window_size=1)  

        self.fcb2 = FCB(512, 128, dropout)
        self.Sparse2 = Sparse_PatchAE(128, 128, depth=4, window_size=1)

        self.fcb3 = FCB(128, 64, dropout)
        self.Sparse3 = Sparse_PatchAE(64, 64, depth=4, window_size=1)

        self.fcb4 = FCB(64, 32, dropout)
        self.Sparse4 = Sparse_PatchAE(32, 32, depth=4, window_size=1)

        self.fcb5 = FCB(32, 8, dropout)
        self.Sparse5 = Sparse_PatchAE(8, 8, depth=4, window_size=1)

    def forward(self, x):
        x1 = self.fcb1(x)
        y1 = self.Sparse1(x1)
        x2 = self.fcb2(x1)
        y2 = self.Sparse2(x2)
        x3 = self.fcb3(x2)
        y3 = self.Sparse3(x3)
        x4 = self.fcb4(x3)
        y4 = self.Sparse4(x4)
        x5 = self.fcb5(x4)
        y5 = self.Sparse5(x5)
        return x1, x2, x3, x4, x5, y1, y2, y3, y4, y5

# %%
class Decoder(nn.Module):
    def __init__(self, output_size, dropout=0.1):
        super().__init__()
        self.fcb5 = FCB(8 + 8, 32, dropout)
        self.fcb4 = FCB(32 + 32, 64, dropout)
        self.fcb3 = FCB(64 + 64, 128, dropout)
        self.fcb2 = FCB(128 + 128, 512, dropout)
        self.fcb1 = FCB(512 + 512, output_size, dropout)

    def forward(self, x1, x2, x3, x4, x5, y1, y2, y3, y4, y5):
        y51 = torch.cat([x5, y5], dim=1)
        y41 = self.fcb5(y51)
        y41 = torch.cat([y41, y4], dim=1)
        y31 = self.fcb4(y41)
        y31 = torch.cat([y31, y3], dim=1)
        y21 = self.fcb3(y31)
        y21 = torch.cat([y21, y2], dim=1)
        y11 = self.fcb2(y21)
        y11 = torch.cat([y11, y1], dim=1)
        output = self.fcb1(y11)
        return output

# %%
class AutoCoder(nn.Module):
    def __init__(self, input_size, output_size, dropout=0.1):
        super().__init__()
        self.encoder = Encoder(input_size, dropout)
        self.decoder = Decoder(output_size, dropout)

    def forward(self, x):
        x1, x2, x3, x4, x5, y1, y2, y3, y4, y5 = self.encoder(x)
        output = self.decoder(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5)
        return output

# %%
def huber_loss(pred, target, delta=1.3):
    error = pred - target
    abs_error = torch.abs(error)
    quadratic = torch.clamp(abs_error, max=delta)
    linear = abs_error - quadratic
    loss = 0.5 * quadratic ** 2 + delta * linear
    return loss.mean()

# %%
#Model initialization
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Loading universal denoiser weights (pre-trained 2D model)
model = AutoCoder(input_size=w1*w2*w3, output_size=w1*w2*w3, dropout=0.1).to(device)
model.decoder.fcb1 = torch.nn.Linear(1024, w1*w2*w3).to(device)

# Loading previously trained universal weights
model.load_state_dict(torch.load('Amir 3d Pre-trained.pth', map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))  
                                 

print("Universal denoiser weights loaded successfully")

# Fine-tuning parameters configuration
optimizer = torch.optim.Adam(model.parameters(), lr=0.0004)
num_epochs = 150
mask_ratio = 0.25

#Training loop
print("Start Fine-tuning on Target Area...")
prev_train_loss = float('inf')
loss_train = []
loss_valid = []

for epoch in range(num_epochs):
    
    model.train()
    train_loss = 0.0
    for batch in finetune_loader:
        noisy_patch = batch[0].to(device)
        
        # Generate a [0, 1) uniform random number matrix with the same shape as the input
        rand_tensor = torch.rand_like(noisy_patch)
        random_mask_2d = rand_tensor < mask_ratio
        input_patch = noisy_patch * (~random_mask_2d)
        target_patch = noisy_patch
        
        optimizer.zero_grad()
        outputs = model(input_patch)
        
       #Loss calculation: only focus on masked scatter points
        rec_loss = huber_loss(outputs[random_mask_2d], target_patch[random_mask_2d], delta=1.3)
        loss = rec_loss
        
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        
        train_loss += loss.item() * input_patch.size(0)
    
    train_loss = train_loss / len(finetune_noisy)
    loss_train.append(train_loss)
    
     #Validation phase (automatically skipped because valid_loader is empty)
    model.eval()
    valid_loss = 0.0
    with torch.no_grad():
        for batch in valid_loader:  
            valid_patch = batch[0].to(device)
            
            rand_tensor_val = torch.rand_like(valid_patch)
            random_mask_2d_val = rand_tensor_val < mask_ratio
            input_val_patch = valid_patch * (~random_mask_2d_val)
            
            outputs = model(input_val_patch)
            rec_loss_val = huber_loss(outputs[random_mask_2d_val], valid_patch[random_mask_2d_val], delta=1.3)
            
            valid_loss += rec_loss_val.item() * valid_patch.size(0)
    
   
    if len(valid_noisy) > 0:
        valid_loss = valid_loss / len(valid_noisy)
    else:
        valid_loss = None  
    
    loss_valid.append(valid_loss)
    
    
    if valid_loss is not None:
        print(f"Epoch[{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}")
    else:
        print(f"Epoch[{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f} ")
    
    # Saving best model (based on training loss)
    if train_loss < prev_train_loss:
        prev_train_loss = train_loss
        torch.save(model.state_dict(), 'real3d_best_Fine-tune training.pth')
        print(f"  Updating best model，Train Loss: {train_loss:.6f}")


print("=" * 60)
print("Fine-tuning completed！")
print(f"Total training {num_epochs} 个epoch")
print(f"Saved weight file:")
for epoch in save_epochs:
    if epoch <= num_epochs:
        print(f"  - real3d_best_Fine-tune training.pth")
print(f"  - real3d_best_Fine-tune training.pth ")
# Out:
# 已加载通用去噪器权重
# Start Fine-tuning on Target Area...
# Epoch[1/200], Train Loss: 0.1280 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.127987
# Epoch[2/200], Train Loss: 0.1066 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.106574
# Epoch[3/200], Train Loss: 0.1000 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.099988
# Epoch[4/200], Train Loss: 0.0963 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.096274
# Epoch[5/200], Train Loss: 0.0938 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.093822
# Epoch[6/200], Train Loss: 0.0947 (无验证集)
# Epoch[7/200], Train Loss: 0.0913 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.091250
# Epoch[8/200], Train Loss: 0.0900 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.089955
# Epoch[9/200], Train Loss: 0.0890 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.088966
# Epoch[10/200], Train Loss: 0.0881 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_10.pth
#   -> 保存最佳模型，Train Loss: 0.088090
# Epoch[11/200], Train Loss: 0.0873 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.087275
# Epoch[12/200], Train Loss: 0.0864 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.086385
# Epoch[13/200], Train Loss: 0.0857 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.085706
# Epoch[14/200], Train Loss: 0.0851 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.085050
# Epoch[15/200], Train Loss: 0.0844 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_15.pth
#   -> 保存最佳模型，Train Loss: 0.084421
# Epoch[16/200], Train Loss: 0.0839 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.083915
# Epoch[17/200], Train Loss: 0.0833 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.083323
# Epoch[18/200], Train Loss: 0.0828 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.082844
# Epoch[19/200], Train Loss: 0.0823 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.082336
# Epoch[20/200], Train Loss: 0.0819 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_20.pth
#   -> 保存最佳模型，Train Loss: 0.081936
# Epoch[21/200], Train Loss: 0.0815 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.081508
# Epoch[22/200], Train Loss: 0.0812 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.081162
# Epoch[23/200], Train Loss: 0.0912 (无验证集)
# Epoch[24/200], Train Loss: 0.0822 (无验证集)
# Epoch[25/200], Train Loss: 0.0813 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_25.pth
# Epoch[26/200], Train Loss: 0.0808 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.080789
# Epoch[27/200], Train Loss: 0.0804 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.080419
# Epoch[28/200], Train Loss: 0.0802 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.080189
# Epoch[29/200], Train Loss: 0.0799 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.079918
# Epoch[30/200], Train Loss: 0.0796 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_30.pth
#   -> 保存最佳模型，Train Loss: 0.079631
# Epoch[31/200], Train Loss: 0.0794 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.079450
# Epoch[32/200], Train Loss: 0.0791 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.079135
# Epoch[33/200], Train Loss: 0.0788 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.078791
# Epoch[34/200], Train Loss: 0.0786 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.078615
# Epoch[35/200], Train Loss: 0.0784 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_35.pth
#   -> 保存最佳模型，Train Loss: 0.078357
# Epoch[36/200], Train Loss: 0.0781 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.078098
# Epoch[37/200], Train Loss: 0.0780 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.077957
# Epoch[38/200], Train Loss: 0.0776 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.077623
# Epoch[39/200], Train Loss: 0.0774 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.077442
# Epoch[40/200], Train Loss: 0.0772 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_40.pth
#   -> 保存最佳模型，Train Loss: 0.077218
# Epoch[41/200], Train Loss: 0.0770 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.077042
# Epoch[42/200], Train Loss: 0.0768 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.076843
# Epoch[43/200], Train Loss: 0.0767 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.076655
# Epoch[44/200], Train Loss: 0.0765 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.076495
# Epoch[45/200], Train Loss: 0.0763 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_45.pth
#   -> 保存最佳模型，Train Loss: 0.076271
# Epoch[46/200], Train Loss: 0.0762 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.076184
# Epoch[47/200], Train Loss: 0.0760 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.076030
# Epoch[48/200], Train Loss: 0.0758 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.075802
# Epoch[49/200], Train Loss: 0.0757 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.075696
# Epoch[50/200], Train Loss: 0.0755 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_50.pth
#   -> 保存最佳模型，Train Loss: 0.075513
# Epoch[51/200], Train Loss: 0.0754 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.075360
# Epoch[52/200], Train Loss: 0.0752 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.075249
# Epoch[53/200], Train Loss: 0.0830 (无验证集)
# Epoch[54/200], Train Loss: 0.0767 (无验证集)
# Epoch[55/200], Train Loss: 0.0756 (无验证集)
# Epoch[56/200], Train Loss: 0.0751 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.075090
# Epoch[57/200], Train Loss: 0.0749 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.074920
# Epoch[58/200], Train Loss: 0.0807 (无验证集)
# Epoch[59/200], Train Loss: 0.0776 (无验证集)
# Epoch[60/200], Train Loss: 0.0759 (无验证集)
# Epoch[61/200], Train Loss: 0.0753 (无验证集)
# Epoch[62/200], Train Loss: 0.0750 (无验证集)
# Epoch[63/200], Train Loss: 0.0747 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.074735
# Epoch[64/200], Train Loss: 0.0746 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.074581
# Epoch[65/200], Train Loss: 0.0744 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.074446
# Epoch[66/200], Train Loss: 0.0743 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.074347
# Epoch[67/200], Train Loss: 0.0742 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.074180
# Epoch[68/200], Train Loss: 0.0741 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.074051
# Epoch[69/200], Train Loss: 0.0740 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073992
# Epoch[70/200], Train Loss: 0.0739 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073890
# Epoch[71/200], Train Loss: 0.0737 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073718
# Epoch[72/200], Train Loss: 0.0736 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073644
# Epoch[73/200], Train Loss: 0.0735 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073470
# Epoch[74/200], Train Loss: 0.0734 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073412
# Epoch[75/200], Train Loss: 0.0733 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073337
# Epoch[76/200], Train Loss: 0.0733 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073265
# Epoch[77/200], Train Loss: 0.0731 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.073095
# Epoch[78/200], Train Loss: 0.0730 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072950
# Epoch[79/200], Train Loss: 0.0729 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072868
# Epoch[80/200], Train Loss: 0.0729 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072851
# Epoch[81/200], Train Loss: 0.0727 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072725
# Epoch[82/200], Train Loss: 0.0726 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072641
# Epoch[83/200], Train Loss: 0.0726 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072568
# Epoch[84/200], Train Loss: 0.0725 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072498
# Epoch[85/200], Train Loss: 0.0724 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072382
# Epoch[86/200], Train Loss: 0.0723 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072263
# Epoch[87/200], Train Loss: 0.0722 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072212
# Epoch[88/200], Train Loss: 0.0721 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072090
# Epoch[89/200], Train Loss: 0.0720 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.072042
# Epoch[90/200], Train Loss: 0.0720 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071966
# Epoch[91/200], Train Loss: 0.0719 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071932
# Epoch[92/200], Train Loss: 0.0718 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071831
# Epoch[93/200], Train Loss: 0.0717 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071704
# Epoch[94/200], Train Loss: 0.0717 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071696
# Epoch[95/200], Train Loss: 0.0716 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071604
# Epoch[96/200], Train Loss: 0.0716 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071566
# Epoch[97/200], Train Loss: 0.0715 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071486
# Epoch[98/200], Train Loss: 0.0714 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071402
# Epoch[99/200], Train Loss: 0.0713 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071305
# Epoch[100/200], Train Loss: 0.0713 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_100.pth
# Epoch[101/200], Train Loss: 0.0712 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071234
# Epoch[102/200], Train Loss: 0.0711 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071145
# Epoch[103/200], Train Loss: 0.0711 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071100
# Epoch[104/200], Train Loss: 0.0711 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.071066
# Epoch[105/200], Train Loss: 0.0710 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070978
# Epoch[106/200], Train Loss: 0.0709 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070934
# Epoch[107/200], Train Loss: 0.0709 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070879
# Epoch[108/200], Train Loss: 0.0708 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070771
# Epoch[109/200], Train Loss: 0.0707 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070716
# Epoch[110/200], Train Loss: 0.0708 (无验证集)
# Epoch[111/200], Train Loss: 0.0707 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070667
# Epoch[112/200], Train Loss: 0.0706 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070596
# Epoch[113/200], Train Loss: 0.0705 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070503
# Epoch[114/200], Train Loss: 0.0704 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070430
# Epoch[115/200], Train Loss: 0.0705 (无验证集)
# Epoch[116/200], Train Loss: 0.0703 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070340
# Epoch[117/200], Train Loss: 0.0703 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070284
# Epoch[118/200], Train Loss: 0.0703 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070263
# Epoch[119/200], Train Loss: 0.0702 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070201
# Epoch[120/200], Train Loss: 0.0702 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_120.pth
#   -> 保存最佳模型，Train Loss: 0.070189
# Epoch[121/200], Train Loss: 0.0702 (无验证集)
# Epoch[122/200], Train Loss: 0.0701 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070109
# Epoch[123/200], Train Loss: 0.0700 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.070032
# Epoch[124/200], Train Loss: 0.0700 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069999
# Epoch[125/200], Train Loss: 0.0699 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069949
# Epoch[126/200], Train Loss: 0.0699 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069872
# Epoch[127/200], Train Loss: 0.0699 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069853
# Epoch[128/200], Train Loss: 0.0697 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069745
# Epoch[129/200], Train Loss: 0.0698 (无验证集)
# Epoch[130/200], Train Loss: 0.0697 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069693
# Epoch[131/200], Train Loss: 0.0697 (无验证集)
# Epoch[132/200], Train Loss: 0.0697 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069670
# Epoch[133/200], Train Loss: 0.0696 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069576
# Epoch[134/200], Train Loss: 0.0695 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069533
# Epoch[135/200], Train Loss: 0.0695 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069466
# Epoch[136/200], Train Loss: 0.0694 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069428
# Epoch[137/200], Train Loss: 0.0694 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069413
# Epoch[138/200], Train Loss: 0.0693 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069349
# Epoch[139/200], Train Loss: 0.0693 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069318
# Epoch[140/200], Train Loss: 0.0693 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069298
# Epoch[141/200], Train Loss: 0.0692 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069211
# Epoch[142/200], Train Loss: 0.0692 (无验证集)
# Epoch[143/200], Train Loss: 0.0692 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069195
# Epoch[144/200], Train Loss: 0.0692 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069170
# Epoch[145/200], Train Loss: 0.0691 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069091
# Epoch[146/200], Train Loss: 0.0691 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069068
# Epoch[147/200], Train Loss: 0.0690 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.069020
# Epoch[148/200], Train Loss: 0.0690 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068965
# Epoch[149/200], Train Loss: 0.0690 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068958
# Epoch[150/200], Train Loss: 0.0689 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_150.pth
#   -> 保存最佳模型，Train Loss: 0.068886
# Epoch[151/200], Train Loss: 0.0689 (无验证集)
# Epoch[152/200], Train Loss: 0.0688 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068842
# Epoch[153/200], Train Loss: 0.0689 (无验证集)
# Epoch[154/200], Train Loss: 0.0688 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068800
# Epoch[155/200], Train Loss: 0.0687 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068739
# Epoch[156/200], Train Loss: 0.0687 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068726
# Epoch[157/200], Train Loss: 0.0686 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068644
# Epoch[158/200], Train Loss: 0.0686 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068622
# Epoch[159/200], Train Loss: 0.0686 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068598
# Epoch[160/200], Train Loss: 0.0686 (无验证集)
# Epoch[161/200], Train Loss: 0.0686 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068576
# Epoch[162/200], Train Loss: 0.0686 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068554
# Epoch[163/200], Train Loss: 0.0685 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068522
# Epoch[164/200], Train Loss: 0.0685 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068465
# Epoch[165/200], Train Loss: 0.0685 (无验证集)
# Epoch[166/200], Train Loss: 0.0684 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068442
# Epoch[167/200], Train Loss: 0.0684 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068382
# Epoch[168/200], Train Loss: 0.0683 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068349
# Epoch[169/200], Train Loss: 0.0683 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068338
# Epoch[170/200], Train Loss: 0.0683 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_170.pth
#   -> 保存最佳模型，Train Loss: 0.068268
# Epoch[171/200], Train Loss: 0.0683 (无验证集)
# Epoch[172/200], Train Loss: 0.0683 (无验证集)
# Epoch[173/200], Train Loss: 0.0682 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068170
# Epoch[174/200], Train Loss: 0.0682 (无验证集)
# Epoch[175/200], Train Loss: 0.0682 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068152
# Epoch[176/200], Train Loss: 0.0682 (无验证集)
# Epoch[177/200], Train Loss: 0.0681 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068100
# Epoch[178/200], Train Loss: 0.0681 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068084
# Epoch[179/200], Train Loss: 0.0680 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.068023
# Epoch[180/200], Train Loss: 0.0681 (无验证集)
# Epoch[181/200], Train Loss: 0.0680 (无验证集)
# Epoch[182/200], Train Loss: 0.0680 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067960
# Epoch[183/200], Train Loss: 0.0680 (无验证集)
# Epoch[184/200], Train Loss: 0.0679 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067889
# Epoch[185/200], Train Loss: 0.0679 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067854
# Epoch[186/200], Train Loss: 0.0678 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067847
# Epoch[187/200], Train Loss: 0.0678 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067829
# Epoch[188/200], Train Loss: 0.0678 (无验证集)
# Epoch[189/200], Train Loss: 0.0679 (无验证集)
# Epoch[190/200], Train Loss: 0.0677 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067747
# Epoch[191/200], Train Loss: 0.0678 (无验证集)
# Epoch[192/200], Train Loss: 0.0677 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067741
# Epoch[193/200], Train Loss: 0.0677 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067720
# Epoch[194/200], Train Loss: 0.0677 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067662
# Epoch[195/200], Train Loss: 0.0676 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067639
# Epoch[196/200], Train Loss: 0.0676 (无验证集)
# Epoch[197/200], Train Loss: 0.0676 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067605
# Epoch[198/200], Train Loss: 0.0676 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067587
# Epoch[199/200], Train Loss: 0.0676 (无验证集)
#   -> 保存最佳模型，Train Loss: 0.067555
# Epoch[200/200], Train Loss: 0.0675 (无验证集)
#   ✅ 已保存指定epoch权重: real3d 20 15 15 2 2 2 0.0004_epoch_200.pth
#   -> 保存最佳模型，Train Loss: 0.067539
# ============================================================
# 微调完成！
# 共训练 200 个epoch
# 保存的权重文件:
#   - real3d 20 15 15 2 2 2 0.0004_epoch_10.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_15.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_20.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_25.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_30.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_35.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_40.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_45.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_50.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_100.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_120.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_150.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_170.pth
#   - real3d 20 15 15 2 2 2 0.0004_epoch_200.pth
#   - real3d 20 15 15 2 2 2 0.0004_best_finetuned.pth (最佳模型)

# %%
#### Inference and post-processing
model = AutoCoder(input_size=w1*w2*w3, output_size=w1*w2*w3, dropout=0.1).to(device)
model.decoder.fcb1 = torch.nn.Linear(1024, w1*w2*w3).to(device)# Ensure structural alignment
model.load_state_dict(torch.load('real3d_best_Fine-tune training.pth', map_location=torch.device('cuda' if torch.cuda.is_available() else 'cpu')))
model.eval()

# Full-data inference
with torch.no_grad():
    Pdata_noisy = Pdata_noisy.to(device)
    outputs = model(Pdata_noisy)
    
    # Convert to numpy array for fine processing
    outputs = outputs.cpu().numpy()
   # Obtain the absolute maximum value of the entire output data as the baseline
    max_amp = np.max(np.abs(outputs))
    threshold = max_amp * 0.008  
    
    outputs = np.sign(outputs) * np.maximum(np.abs(outputs) - threshold, 0)
    
print("== Inference output statistics ===")
print(f"Total number of output patches: {outputs.shape[0]}")
print(f"Total number of output patches: {np.count_nonzero(outputs.any(axis=1))}")
print(f"Output maximum value: {outputs.max():.4f},  minimum value: {outputs.min():.4f},  mean value: {outputs.mean():.4f}")

# Inverse blocking to merge into a complete image
denoised_data = patch3d_inv(
    outputs, 
    n1=nz, n2=nx, n3=ny, 
    l1=w1, l2=w2, l3=w3,  
    s1=s1, s2=s2, s3=s3
)
#  Calculate denoising effect metrics
if 'Dc' in locals() or 'Dc' in globals():

    def calculate_snr(clean, denoised):
        noise = denoised - clean
        signal_power = np.mean(clean ** 2)
        noise_power = np.mean(noise ** 2)
        if noise_power == 0:
            return float('inf')
        snr = 10 * np.log10(signal_power / noise_power)
        return snr
    
    # Calculate SNR after denoising
    snr_after = calculate_snr(Dc, denoised_data)
    # Calculate SNR before denoising
    noise_before = Dn - Dc
    signal_power_before = np.mean(Dc ** 2)
    noise_power_before = np.mean(noise_before ** 2)
    snr_before = 10 * np.log10(signal_power_before / noise_power_before)
    
    print("=" * 50)
    print(f"Denoising effect evaluation:")
    print(f"  SNR (before denoising)）: {snr_before:.2f} dB")
    print(f"  SNR (after denoising): {snr_after:.2f} dB")
    print(f"  SNR improvement: {snr_after - snr_before:.2f} dB")
    print("=" * 50)

else:
    print("Clean data Dc not found, cannot calculate quantitative metrics (normal for unsupervised learning)")

#Save data
# Save only 1 core variable: 
save_dict = {
    'D_denoised': denoised_data
}


output_path = 'real3d_best_Fine-tune training.mat'
sio.savemat(output_path, save_dict, do_compression=True)


print(f"【Unsupervised denoising results saved to: {output_path}】")
print(f"Saved variable name: D_denoised，Data size: {denoised_data.shape}")

print("== Final output statistics ===")
print(f'Denoised data shape: {denoised_data.shape}')
print(f'Denoised data range: [{denoised_data.min():.4f}, {denoised_data.max():.4f}]')
print(f'Denoised data mean: {denoised_data.mean():.4f}')
print(f'☑️ Denoising results saved to: {output_path}')
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[53], line 10
#       8 with torch.no_grad():
#       9     Pdata_noisy = Pdata_noisy.to(device)
# ---> 10     outputs = model(Pdata_noisy)
#      12     # 转换为 numpy 数组进行精细处理
#      13     outputs = outputs.cpu().numpy()
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[45], line 8, in AutoCoder.forward(self, x)
#       7 def forward(self, x):
# ----> 8     x1, x2, x3, x4, x5, y1, y2, y3, y4, y5 = self.encoder(x)
#       9     output = self.decoder(x1, x2, x3, x4, x5, y1, y2, y3, y4, y5)
#      10     return output
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[43], line 21, in Encoder.forward(self, x)
#      19 def forward(self, x):
#      20     x1 = self.fcb1(x)
# ---> 21     y1 = self.Sparse1(x1)
#      22     x2 = self.fcb2(x1)
#      23     y2 = self.Sparse2(x2)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# Cell In[42], line 77, in Sparse_PatchAE.forward(self, x)
#      75 cls_tokens = self.cls_token.expand(B, -1, -1)
#      76 x = torch.cat((cls_tokens, x), dim=1)
# ---> 77 x = x + self.pos_embed
#      79 for norm1, attn, norm2, mlp in self.blocks:
#      80     x = x + attn(norm1(x))
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 218.00 MiB. GPU 0 has a total capacity of 23.56 GiB of which 200.00 MiB is free. Including non-PyTorch memory, this process has 3.05 GiB memory in use. Process 559 has 3.80 GiB memory in use. Process 562 has 1.81 GiB memory in use. Process 2008 has 14.68 GiB memory in use. Of the allocated memory 2.69 GiB is allocated by PyTorch, and 50.73 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
